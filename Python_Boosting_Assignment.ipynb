# %% [markdown]
# # Boosting Techniques Assignment (DA-AG-015)
#
# All questions with answers.

# %% [markdown]
# ### Question 1: What is Boosting in Machine Learning? Explain how it improves weak learners.
#
# **Answer:**
# Boosting is an ensemble learning technique that combines multiple weak learners to form a strong learner. It works by training models sequentially, where each new model focuses on correcting the errors made by previous models. This improves performance by reducing bias and variance.

# %% [markdown]
# ### Question 2: What is the difference between AdaBoost and Gradient Boosting in terms of how models are trained?
#
# **Answer:**
# AdaBoost assigns weights to misclassified samples and adjusts them iteratively, focusing more on difficult cases. Gradient Boosting builds models sequentially by optimizing a loss function using gradient descent.

# %% [markdown]
# ### Question 3: How does regularization help in XGBoost?
#
# **Answer:**
# Regularization in XGBoost prevents overfitting by penalizing complex models. It includes L1 and L2 regularization, which control model complexity and improve generalization.

# %% [markdown]
# ### Question 4: Why is CatBoost considered efficient for handling categorical data?
#
# **Answer:**
# CatBoost efficiently handles categorical data using techniques like ordered boosting and target encoding, reducing the need for preprocessing like one-hot encoding.

# %% [markdown]
# ### Question 5: What are some real-world applications where boosting techniques are preferred over bagging methods?
#
# **Answer:**
# Boosting is preferred in applications like fraud detection, credit scoring, medical diagnosis, and recommendation systems where high accuracy and handling complex patterns are required.

# %% [markdown]
# ### Question 6: AdaBoost Classifier on Breast Cancer dataset

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2)

model = AdaBoostClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# %% [markdown]
# ### Question 7: Gradient Boosting Regressor on California Housing dataset

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

data = fetch_california_housing()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2)

model = GradientBoostingRegressor()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("R2 Score:", r2_score(y_test, y_pred))

# %% [markdown]
# ### Question 8: XGBoost Classifier with GridSearchCV

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier

data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2)

params = {'learning_rate': [0.01, 0.1, 0.2]}

model = GridSearchCV(XGBClassifier(use_label_encoder=False, eval_metric='logloss'), params)
model.fit(X_train, y_train)

print("Best Params:", model.best_params_)
print("Accuracy:", model.score(X_test, y_test))

# %% [markdown]
# ### Question 9: CatBoost Classifier with Confusion Matrix

# %%
from catboost import CatBoostClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2)

model = CatBoostClassifier(verbose=0)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True)
plt.show()

# %% [markdown]
# ### Question 10: FinTech Loan Default Pipeline

# %%
# Steps:
# 1. Data preprocessing: handle missing values, encode categorical data
# 2. Model selection: use XGBoost or CatBoost for mixed data
# 3. Hyperparameter tuning using GridSearchCV or RandomizedSearchCV
# 4. Evaluation metrics: Precision, Recall, F1-score, ROC-AUC (for imbalance)
# 5. Business impact: Better risk assessment, reduced losses

print("Pipeline described successfully")
