# %% [markdown]
# THEORY QUESTIONS

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?

# %% [markdown]
# Interpreted languages execute code line by line at runtime, while compiled languages translate the entire program into machine code before execution.

# %% [markdown]
# 2. What is exception handling in Python?

# %% [markdown]
# Exception handling is a way to manage runtime errors so the program does not crash unexpectedly.

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?

# %% [markdown]
# The finally block always executes and is used to release resources.

# %% [markdown]
# 4. What is logging in Python?

# %% [markdown]
# Logging is used to record messages about program execution.

# %% [markdown]
# 5. What is the significance of the __del__ method in Python?

# %% [markdown]
# It is called when an object is destroyed and is used to free resources.

# %% [markdown]
# 6. What is the difference between import and from import in Python?

# %% [markdown]
# import loads the whole module, while from import loads specific parts.

# %% [markdown]
# 7. How can you handle multiple exceptions in Python?

# %% [markdown]
# By using multiple except blocks or a tuple of exceptions.

# %% [markdown]
# 8. What is the purpose of the with statement?

# %% [markdown]
# It manages resources automatically and closes files safely.

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing?

# %% [markdown]
# Multithreading uses threads in one process, multiprocessing uses multiple processes.

# %% [markdown]
# 10. What are the advantages of logging?

# %% [markdown]
# It helps debugging, tracking errors, and monitoring execution.

# %% [markdown]
# 11. What is memory management in Python?

# %% [markdown]
# It handles allocation and deallocation of memory.

# %% [markdown]
# 12. What are the basic steps in exception handling?

# %% [markdown]
# Using try, except, else, and finally blocks.

# %% [markdown]
# 13. Why is memory management important?

# %% [markdown]
# It prevents memory leaks and improves performance.

# %% [markdown]
# 14. What is the role of try and except?

# %% [markdown]
# try contains risky code and except handles errors.

# %% [markdown]
# 15. How does garbage collection work?

# %% [markdown]
# Python removes unused objects using reference counting and garbage collection.

# %% [markdown]
# 16. What is the purpose of else in exception handling?

# %% [markdown]
# It runs when no exception occurs.

# %% [markdown]
# 17. What are common logging levels?

# %% [markdown]
# DEBUG, INFO, WARNING, ERROR, CRITICAL.

# %% [markdown]
# 18. Difference between os.fork and multiprocessing?

# %% [markdown]
# os.fork is Unix-specific, multiprocessing is cross-platform.

# %% [markdown]
# 19. Why is closing a file important?

# %% [markdown]
# It frees system resources and saves data.

# %% [markdown]
# 20. Difference between file.read and file.readline?

# %% [markdown]
# file.read reads all content, readline reads one line.

# %% [markdown]
# 21. What is logging module used for?

# %% [markdown]
# To record application events.

# %% [markdown]
# 22. What is os module used for in file handling?

# %% [markdown]
# It provides file and directory operations.

# %% [markdown]
# 23. Challenges in memory management?

# %% [markdown]
# Memory leaks and circular references.

# %% [markdown]
# 24. How to raise an exception manually?

# %% [markdown]
# Using the raise keyword.

# %% [markdown]
# 25. Why use multithreading?

# %% [markdown]
# To improve responsiveness and performance.

# %% [markdown]
# PRACTICAL QUESTIONS

# %% [markdown]
# 1. How can you open a file for writing in Python and write a string to it

# %%
with open("file1.txt","w") as f:
    f.write("Hello File")

# %% [markdown]
# 2.  Write a Python program to read the contents of a file and print each line

# %%
with open("file1.txt","r") as f:
    for line in f:
        print(line.strip())

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading

# %%
try:
    open("missing.txt")
except FileNotFoundError:
    print("File not found")

# %% [markdown]
# 4.  Write a Python script that reads from one file and writes its content to another file

# %%
with open("file1.txt","r") as a, open("file2.txt","w") as b:
    b.write(a.read())

# %% [markdown]
# 5. How would you catch and handle division by zero error in Python

# %%
try:
    print(5/0)
except ZeroDivisionError:
    print("Zero Division Error")

# %% [markdown]
# 6.  Write a Python program that logs an error message to a log file when a division by zero exception occurs

# %%
import logging
logging.basicConfig(filename="log.txt",level=logging.ERROR)
try:
    10/0
except ZeroDivisionError:
    logging.error("Division error")

# %% [markdown]
# 7.  How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.info("Info")
logging.warning("Warning")
logging.error("Error")

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling

# %%
try:
    open("abc.txt")
except Exception:
    print("File error")

# %% [markdown]
# 9. How can you read a file line by line and store its content in a list in Python

# %%
with open("file1.txt") as f:
    data=f.readlines()
print(data)

# %% [markdown]
# 10. How can you append data to an existing file in Python

# %%
with open("file1.txt","a") as f:
    f.write("\nAppend Data")

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist.

# %%
try:
    d={}
    print(d["a"])
except KeyError:
    print("Key not found")

# %% [markdown]
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions

# %%
try:
    a=[1]
    print(a[5])
except IndexError:
    print("Index Error")

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python

# %%
import os
print(os.path.exists("file1.txt"))

# %% [markdown]
# 14. Write a program that uses the logging module to log both informational and error messages

# %%
import logging
logging.basicConfig(filename="app.log",level=logging.INFO)
logging.info("Info message")
logging.error("Error message")

# %% [markdown]
# 15.  Write a Python program that prints the content of a file and handles the case when the file is empty

# %%
with open("file1.txt") as f:
    c=f.read()
    print("Empty" if not c else c)

# %% [markdown]
# 17.  Write a Python program to create and write a list of numbers to a file, one number per line

# %%
nums=[1,2,3]
with open("nums.txt","w") as f:
    for i in nums:
        f.write(str(i)+"\n")

# %% [markdown]
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB

# %%
import logging
from logging.handlers import RotatingFileHandler
handler=RotatingFileHandler("rotate.log",maxBytes=1024*1024,backupCount=1)
logger=logging.getLogger()
logger.addHandler(handler)
logger.error("Test")

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block

# %%
try:
    a=[1]
    d={}
    print(a[5])
except (IndexError,KeyError):
    print("Handled")

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in Python

# %%
with open("file1.txt") as f:
    print(f.read())

# %% [markdown]
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word

# %%
with open("file1.txt") as f:
    text=f.read()
    print(text.count("File"))

# %% [markdown]
# 22. How can you check if a file is empty before attempting to read its contents

# %%
import os
print(os.path.getsize("file1.txt")==0)

# %% [markdown]
# 23. Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging
logging.basicConfig(filename="file_error.log",level=logging.ERROR)
try:
    open("no.txt")
except Exception:
    logging.error("File handling error")
