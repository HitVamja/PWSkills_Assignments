# %% [markdown]
# # Supervised Learning: Regression Models and Performance Metrics
#
# ## Question 1
# What is Simple Linear Regression (SLR)? Explain its purpose.
# **Answer:** Simple Linear Regression (SLR) is a statistical method used to model the relationship between one independent variable (X) and one dependent variable (Y) using a straight line.
#
# The purpose of SLR is to:
#
# Understand the relationship between two variables
#
# Predict the value of the dependent variable
#
# Identify trends in data
#
# Example: Predicting house price based on area.
#
# ## Question 2
# What are the key assumptions of Simple Linear Regression?
# **Answer:** Simple Linear Regression has several important assumptions:
#
# Linearity
# The relationship between X and Y should be linear.
#
# Independence
# Observations should be independent of each other.
#
# Homoscedasticity
# The variance of errors should remain constant.
#
# Normal Distribution of Errors
# The residual errors should follow a normal distribution.
#
# No Outliers
# Extreme values should not heavily influence the model.
#
# ## Question 3
# Write the mathematical equation for a simple linear regression model and explain each term.
# **Answer:** The equation is:
#
# ![image.png](attachment:image.png)
#
# Where:
#
# Y → Dependent variable (target value)
#
# X → Independent variable (input feature)
#
# β₀ (Intercept) → Value of Y when X = 0
#
# β₁ (Slope) → Change in Y for a one-unit increase in X
#
# ε (Error term) → Difference between predicted and actual values
#
# ## Question 4
# Provide a real-world example where simple linear regression can be applied.
# **Answer:** Example: Advertising vs Sales
#
# A company wants to predict sales based on advertising budget.
#
# X → Advertising spend
#
# Y → Sales revenue
#
# If advertising increases, sales usually increase.
#
# This relationship can be modeled using Simple Linear Regression.
#
# ## Question 5
# What is the method of least squares in linear regression?
# **Answer:** The Least Squares Method is used to find the best-fitting regression line.
#
# It works by minimizing the sum of the squared differences between actual values and predicted values.
#
# Formula: ![image-2.png](attachment:image-2.png)
#
# ## Question 6
# What is Logistic Regression? How does it differ from Linear Regression?
# **Answer:** Logistic Regression is a classification algorithm used to predict categorical outcomes.
#
# Example:
#
# Yes / No
#
# 0 / 1
#
# Pass / Fail
#
# ## Question 7
# Name and briefly describe three common evaluation metrics for regression models.
# **Answer:** R-squared (R²) measures how well the regression model fits the data.
#
# It shows the percentage of variation in the dependent variable explained by the model.
#
# ## Question 8
# Provide a real-world example where simple linear regression can be applied.
# **Answer:** Average of absolute differences between predicted and actual values.
#
# ## Question 9
# Write Python code to fit a simple linear regression model using scikit-learn and print the slope and intercept.
# (Include your Python code and output in the code box below.)
# **Answer:** Study Hours vs Exam Score
#
# X → Number of hours studied
#
# Y → Exam score
#
# Using SLR, we can predict student marks based on study time.

# %% [markdown]
# ## Question 10
# How do you interpret the coefficients in a simple linear regression model?

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 4, 5, 4, 5])

# Create model
model = LinearRegression()

# Fit model
model.fit(X, y)

# Print slope and intercept
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 0.6
# Intercept: 2.2
