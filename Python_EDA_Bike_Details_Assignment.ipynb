# %% [markdown]
# # EDA Assignment – Bike Details Dataset
#
# Assignment Code: DA-AG-009

# %% [markdown]
# ## Question 1
# Read the dataset, show first 10 rows, shape and columns.

# %%
import pandas as pd

df = pd.read_csv("Bike_Details.csv")
df.head(10), df.shape, df.columns

# %% [markdown]
# ## Question 2
# Check missing values and handling approach.

# %%
df.isnull().sum()

# Handling: numerical -> median, categorical -> mode

# %% [markdown]
# ## Question 3
# Distribution of selling price.

# %%
import matplotlib.pyplot as plt

df['selling_price'].hist()
plt.xlabel("Selling Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Question 4
# Average selling price by seller type.

# %%
df.groupby('seller_type')['selling_price'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Question 5
# Average km_driven by ownership.

# %%
df.groupby('owner')['km_driven'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Question 6
# Outlier removal using IQR.

# %%
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)
IQR = Q3 - Q1

df_clean = df[(df['km_driven'] >= Q1 - 1.5*IQR) & (df['km_driven'] <= Q3 + 1.5*IQR)]
df['km_driven'].describe(), df_clean['km_driven'].describe()

# %% [markdown]
# ## Question 7
# Year vs Selling Price.

# %%
plt.scatter(df['year'], df['selling_price'])
plt.xlabel("Year")
plt.ylabel("Selling Price")
plt.show()

# %% [markdown]
# ## Question 8
# One-hot encoding seller_type.

# %%
df_encoded = pd.get_dummies(df, columns=['seller_type'])
df_encoded.head()

# %% [markdown]
# ## Question 9
# Correlation heatmap.

# %%
import seaborn as sns

corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# ## Question 10
# Summary Findings.
#
# - Selling price is affected by year, km_driven, and seller type.
# - Outliers removed using IQR.
# - One-hot encoding applied to categorical data.
