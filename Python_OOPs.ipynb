# %% [markdown]
# ### 1. What is Object-Oriented Programming (OOP)?
#
# OOP is a programming style that organizes code into objects that contain data and behaviors.

# %% [markdown]
# ### 2. What is a class in OOP?
#
# A class is a blueprint used to create objects.

# %% [markdown]
# ### 3. What is an object in OOP?
#
# An object is an instance of a class and represents a real-world entity.

# %% [markdown]
# ### 4. What is the difference between abstraction and encapsulation?
#
# Abstraction hides complexity, while encapsulation protects data by restricting access.

# %% [markdown]
# ### 5. What are dunder methods in Python?
#
# Dunder methods are special Python methods like __init__ or __str__ used for built‑in behavior.

# %% [markdown]
# ### 6. Explain the concept of inheritance in OOP.
#
# Inheritance allows one class to take properties and methods from another class.

# %% [markdown]
# ### 7. What is polymorphism in OOP?
#
# Polymorphism means the same method name can work in different ways depending on the object.

# %% [markdown]
# ### 8. How is encapsulation achieved in Python?
#
# Encapsulation is achieved using private attributes and getter/setter methods.

# %% [markdown]
# ### 9. What is a constructor in Python?
#
# A constructor is a method (__init__) that initializes object attributes.

# %% [markdown]
# ### 10. What are class and static methods in Python?
#
# A class method works with the class, while a static method is a utility function inside a class.

# %% [markdown]
# ### 11. What is method overloading in Python?
#
# Method overloading means same method name with different arguments (Python simulates it).

# %% [markdown]
# ### 12. What is method overriding in OOP?
#
# Method overriding happens when a child class provides its own version of a parent class method.

# %% [markdown]
# ### 13. What is a property decorator in Python?
#
# A property decorator lets you access a method like an attribute.

# %% [markdown]
# ### 14. Why is polymorphism important in OOP?
#
# It allows flexibility by enabling different objects to respond differently to the same method.

# %% [markdown]
# ### 15. What is an abstract class in Python?
#
# An abstract class cannot be instantiated and contains abstract methods.

# %% [markdown]
# ### 16. What are the advantages of OOP?
#
# OOP makes code reusable, modular, maintainable, and easier to understand.

# %% [markdown]
# ### 17. What is the difference between a class variable and an instance variable?
#
# A class variable is shared by all objects; an instance variable is unique to each object.

# %% [markdown]
# ### 18. What is multiple inheritance in Python?
#
# Multiple inheritance means a class can inherit from more than one parent class.

# %% [markdown]
# ### 19. Explain the purpose of '__str__' and '__repr__' methods in Python.
#
# __str__ gives a readable output; __repr__ gives an unambiguous developer representation.

# %% [markdown]
# ### 20. What is the significance of the 'super()' function in Python?
#
# super() is used to call parent class methods inside child classes.

# %% [markdown]
# ### 21. What is the significance of the '__del__' method in Python?
#
# __del__ runs when an object is deleted and is used for cleanup.

# %% [markdown]
# ### 22. What is the difference between @staticmethod and @classmethod in Python?
#
# @staticmethod works without class/object; @classmethod works with the class.

# %% [markdown]
# ### 23. How does polymorphism work in Python with inheritance?
#
# Child classes override parent methods to give polymorphic behavior.

# %% [markdown]
# ### 24. What is method chaining in Python OOP?
#
# Method chaining means calling multiple methods in one line because each returns self.

# %% [markdown]
# ### 25. What is the purpose of the '__call__' method in Python?
#
# __call__ allows an object to be called like a function.

# %% [markdown]
# # Practical Tasks (Only Questions, No Code)

# %% [markdown]
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print 'Bark!'.

# %%
class Animal:
   def speak(self):
      print("a generic message")
   
class Dog(Animal):
   def speak(self):
      print("Bark!!..")
   
obj = Dog()
obj.speak()
# Out:
# Bark!!..

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
import abc


class Shape:
   @abc.abstractmethod
   def area():
      pass
   
class Circle(Shape):
   def area(self,r):
      return 3.14 * r * r
      
class Rectangle(Shape):
   def area(self,a,b):
      return a * b
   
obj1 = Circle()
obj2 = Rectangle()

print(obj1.area(5))
print(obj2.area(5,5))
# Out:
# 78.5
# 25

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

ev = ElectricCar("Four Wheeler", "Tesla", "85 kWh")
print(ev.type)
print(ev.brand)
print(ev.battery)
# Out:
# Four Wheeler
# Tesla
# 85 kWh

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
class Bird:
   def fly(self):
      print("Birds Flies...")
      
class Sparrow(Bird):
   def fly(self):
      return f"Sparrow Fly..."
      
class Panguin(Bird):
   def fly(self):
      return f"Panguin Can't Fly..."
      
obj1 = Sparrow()
obj2 = Panguin()

print(obj1.fly())
print(obj2.fly())
# Out:
# Sparrow Fly...
# Panguin Can't Fly...

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
   __balance = 0
   def Deposit(self,Amount):
      self.__balance += Amount

   def Withdraw(self,Amount):
      if self.__balance >= Amount:
         self.__balance -= Amount
      else:
         return "Insufficient Balance!!"
   
   def Check_Balance(self):
      return self.__balance
   
   


obj1 = BankAccount()
obj1.Deposit(5000)
obj1.Withdraw(2000)
print("Your Balance is",obj1.Check_Balance())
# Out:
# Your Balance is 3000

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        return "Instrument is playing..."

class Guitar(Instrument):
    def play(self):
        return "Guitar is playing melody."

class Piano(Instrument):
    def play(self):
        return "Piano is playing soft notes."
     
     
instruments = [Guitar(), Piano()]

for i in instruments:
    print(i.play())
# Out:
# Guitar is playing melody.
# Piano is playing soft notes.

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_number(cls, a, b):
        return a + b
    
    @staticmethod
    def Sub_number(a, b):
        return a - b

print(MathOperations.add_number(1, 2))
print(MathOperations.Sub_number(2, 1))
# Out:
# 3
# 1

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
   count = 0
   def __init__(self):
      Person.count += 1
   
   def total_count(self):
      return Person.count
      
   
obj1 = Person()
obj2 = Person()
obj3 = Person()
obj4 = Person()

obj4.total_count()
# Out:
# 4

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the __str__ method to display the fraction as 'numerator/denominator'.

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


f = Fraction(3, 7)
print(f)
# Out:
# 3/7

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(4, 1)
v3 = Vector(4, 1)

result = v1 + v2 + v3
print(result)
# Out:
# (10, 5)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints a greeting message.

# %%
class Person:
   def __init__(self,name,age):
      self.name = name
      self.age = age
      
   def greet(self):
      return f"Hello How are You {self.name}"

obj1 = Person("Heet",20)
obj1.greet()
# Out:
# 'Hello How are You Heet'

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades   

    def average_grade(self):
        return sum(self.grades) / len(self.grades)


s = Student("Heet", [80, 90, 85, 95])
print(s.average_grade())
# Out:
# 87.5

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


r = Rectangle()
r.set_dimensions(10, 5)
print(r.area())
# Out:
# 50

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() based on hours worked and rate. Create a Manager class that adds a bonus.

# %%
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate


class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        base_salary = super().calculate_salary(hours, rate)
        return base_salary + bonus



emp = Employee()
print(emp.calculate_salary(40, 500))

mgr = Manager()
print(mgr.calculate_salary(40, 500, 5000))
# Out:
# 20000
# 25000

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement total_price().

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


p = Product("Laptop", 50000, 2)
print(p.total_price())
# Out:
# 100000

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Implement Cow and Sheep classes.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        return "Cow says Moo"


class Sheep(Animal):
    def sound(self):
        return "Sheep says Baa"



animals = [Cow(), Sheep()]

for a in animals:
    print(a.sound())
# Out:
# Cow says Moo
# Sheep says Baa

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add get_book_info().

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"



b = Book("Atomic Habits", "James Clear", 2018)
print(b.get_book_info())
# Out:
# Title: Atomic Habits, Author: James Clear, Year: 2018

# %% [markdown]
# 18. Create a class House with attributes address and price. Derive Mansion adding number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


m = Mansion("Ahmedabad", 50000000, 12)

print(m.address)
print(m.price)
print(m.number_of_rooms)
# Out:
# Ahmedabad
# 50000000
# 12
