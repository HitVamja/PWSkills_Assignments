# %% [markdown]
# ### 1. What is a Support Vector Machine (SVM)?
#
# **Answer:** SVM is a supervised machine learning algorithm used for classification and regression. It finds the optimal hyperplane that separates different classes with the maximum margin.

# %% [markdown]
# ### 2. What is the difference between Hard Margin and Soft Margin SVM?
#
# **Answer:** Hard Margin SVM requires perfectly separable data without errors, while Soft Margin SVM allows some misclassification to handle noisy or overlapping data.

# %% [markdown]
# ### 3. What is the mathematical intuition behind SVM?
#
# **Answer:** SVM tries to find a hyperplane that maximizes the margin between classes. The margin is the distance between the decision boundary and the nearest data points.

# %% [markdown]
# ### 4. What is the role of Lagrange Multipliers in SVM?
#
# **Answer:** Lagrange multipliers convert the constrained optimization problem into a solvable dual problem and help identify support vectors.

# %% [markdown]
# ### 5. What are Support Vectors in SVM?
#
# **Answer:** Support vectors are the data points closest to the decision boundary that define the position and orientation of the hyperplane.

# %% [markdown]
# ### 6. What is a Support Vector Classifier (SVC)?
#
# **Answer:** SVC is the classification implementation of SVM used to classify data into different categories.

# %% [markdown]
# ### 7. What is a Support Vector Regressor (SVR)?
#
# **Answer:** SVR is the regression version of SVM used to predict continuous numerical values.

# %% [markdown]
# ### 8. What is the Kernel Trick in SVM?
#
# **Answer:** The kernel trick transforms data into a higher dimensional space so non‑linear data can be separated with a linear hyperplane.

# %% [markdown]
# ### 9. Compare Linear Kernel, Polynomial Kernel, and RBF Kernel.
#
# **Answer:** Linear Kernel: used for linearly separable data.
# Polynomial Kernel: used for curved decision boundaries.
# RBF Kernel: most flexible and handles complex nonlinear relationships.

# %% [markdown]
# ### 10. What is the effect of the C parameter in SVM?
#
# **Answer:** C controls the trade‑off between maximizing margin and minimizing classification errors. Large C → fewer errors but smaller margin. Small C → larger margin but more errors.

# %% [markdown]
# ### 11. What is the role of the Gamma parameter in RBF Kernel SVM?
#
# **Answer:** Gamma determines how far the influence of a single training point reaches. High gamma can cause overfitting while low gamma produces smoother boundaries.

# %% [markdown]
# ### 12. What is the Naïve Bayes classifier and why is it called 'Naïve'?
#
# **Answer:** Naïve Bayes is a probabilistic classifier based on Bayes' theorem. It assumes that all features are independent, which is why it is called 'naïve'.

# %% [markdown]
# ### 13. What is Bayes’ Theorem?
#
# **Answer:** Bayes’ theorem calculates conditional probability.
# P(A|B) = (P(B|A) * P(A)) / P(B)

# %% [markdown]
# ### 14. Explain Gaussian, Multinomial, and Bernoulli Naïve Bayes.
#
# **Answer:** Gaussian NB: used for continuous features.
# Multinomial NB: used for count data such as word frequencies.
# Bernoulli NB: used for binary/boolean features.

# %% [markdown]
# ### 15. When should you use Gaussian Naïve Bayes?
#
# **Answer:** When the dataset contains continuous features that follow a normal distribution.

# %% [markdown]
# ### 16. What are the key assumptions made by Naïve Bayes?
#
# **Answer:** 1. Features are independent.
# 2. Each feature contributes equally.
# 3. Data follows assumed probability distribution.

# %% [markdown]
# ### 17. What are the advantages and disadvantages of Naïve Bayes?
#
# **Answer:** Advantages: Fast, simple, works well with small datasets.
# Disadvantages: Strong independence assumption may not hold in real data.

# %% [markdown]
# ### 18. Why is Naïve Bayes a good choice for text classification?
#
# **Answer:** It performs well with high‑dimensional sparse data such as word counts and TF‑IDF vectors.

# %% [markdown]
# ### 19. Compare SVM and Naïve Bayes for classification tasks.
#
# **Answer:** SVM handles complex decision boundaries but may be slower. Naïve Bayes is faster and works well for text but assumes feature independence.

# %% [markdown]
# ### 20. How does Laplace Smoothing help in Naïve Bayes?
#
# **Answer:** It prevents zero probability problems by adding a small constant to all feature counts.

# %% [markdown]
# ### 21. Train an SVM Classifier on the Iris dataset and evaluate accuracy.

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

iris = datasets.load_iris()
X_train,X_test,y_train,y_test = train_test_split(iris.data,iris.target,test_size=0.2)

model = SVC(kernel='linear')
model.fit(X_train,y_train)

pred = model.predict(X_test)
print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# ### 22. Train SVM with Linear and RBF kernels on Wine dataset and compare accuracy.

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

data = load_wine()
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2)

linear = SVC(kernel='linear').fit(X_train,y_train)
rbf = SVC(kernel='rbf').fit(X_train,y_train)

print("Linear Accuracy:",accuracy_score(y_test,linear.predict(X_test)))
print("RBF Accuracy:",accuracy_score(y_test,rbf.predict(X_test)))

# %% [markdown]
# ### 23. Train an SVM Regressor (SVR) and evaluate using MSE.

# %%
from sklearn.svm import SVR
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

data = fetch_california_housing()
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2)

model = SVR()
model.fit(X_train,y_train)

pred = model.predict(X_test)
print("MSE:",mean_squared_error(y_test,pred))

# %% [markdown]
# ### 24. Train Gaussian Naive Bayes on Breast Cancer dataset.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

data = load_breast_cancer()
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2)

model = GaussianNB()
model.fit(X_train,y_train)

pred = model.predict(X_test)
print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# ### 25. Train Multinomial Naive Bayes for text classification.

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

data = fetch_20newsgroups()
vectorizer = CountVectorizer()

X = vectorizer.fit_transform(data.data)
y = data.target

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

model = MultinomialNB()
model.fit(X_train,y_train)

pred = model.predict(X_test)
print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# ### 26. Train Bernoulli Naive Bayes for binary classification.

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X,y = make_classification(n_samples=1000,n_features=10)

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

model = BernoulliNB()
model.fit(X_train,y_train)

pred = model.predict(X_test)
print("Accuracy:",accuracy_score(y_test,pred))

# %% [markdown]
# ### 27. Tune SVM hyperparameters using GridSearchCV.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.datasets import load_iris

data = load_iris()
X = data.data
y = data.target

params = {'C':[0.1,1,10],'kernel':['linear','rbf'],'gamma':['scale','auto']}

grid = GridSearchCV(SVC(),params,cv=5)
grid.fit(X,y)

print("Best Parameters:",grid.best_params_)

# %% [markdown]
# ### 28. Compare SVM and Naive Bayes on the same dataset.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

data = load_iris()
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2)

svm = SVC().fit(X_train,y_train)
nb = GaussianNB().fit(X_train,y_train)

print("SVM:",accuracy_score(y_test,svm.predict(X_test)))
print("Naive Bayes:",accuracy_score(y_test,nb.predict(X_test)))

# %% [markdown]
# ### 29. Evaluate SVM using Precision, Recall and F1-score.

# %%
from sklearn.metrics import classification_report
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

data = load_iris()
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2)

model = SVC()
model.fit(X_train,y_train)

pred = model.predict(X_test)

print(classification_report(y_test,pred))

# %% [markdown]
# ### 30. Visualize Confusion Matrix for SVM.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

data = load_iris()
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2)

model = SVC()
model.fit(X_train,y_train)

pred = model.predict(X_test)

cm = confusion_matrix(y_test,pred)
sns.heatmap(cm,annot=True,fmt='d')
plt.show()
